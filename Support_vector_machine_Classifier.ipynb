# %% [markdown]
# # SVM we use to classify the linear and nonlinear data here we are clasifying the complex data too by using kernel trick using the feature map in the different space where the data is linearly classified.

# %% [markdown]
# We will again load the iris dataset in to the file.

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
df_n = load_iris()
len(df_n)
# Out:
# 8

# %%
dir(df_n)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
# now we are making as data frame of columns feature_names

df_1 = pd.DataFrame(df_n.data, columns = df_n.feature_names) # here the data is in df.data because all the deta set

# have sepal length (cm)	sepal width (cm)	petal length (cm)	petal width (cm) 
df_1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df_1['target'] = df_n.target
df_1.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
# here we can see that we have extracted the information from the given dataset now we will be able to easily draw 
# the plots 


# now we want to have taget with the name of the flowers also then here we will use a small sunction 

df_1['flower_name'] = df_1.target.apply(lambda x : df.target_names[x] )
df_1.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %% [markdown]
# # Plotting and understanding the data here we will take each catagory(target) of the data points to a individual data frame and will plt the graph so that we can clearly see the corelation between them with the help of plotting the graph with the same features

# %%
# deviding the data frame in 3 different data frames 

df0 = df_1[df_1.target ==0] # extracting the data for all the satosa flowers 
df1 = df_1[df_1.target ==1]
df2 = df_1[df_1.target ==2]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 106                4.9               2.5                4.5               1.7
# 107                7.3               2.9                6.3               1.8
# 108                6.7               2.5                5.8               1.8
# 109                7.2               3.6                6.1               2.5
# 110                6.5               3.2                5.1               2.0
# ...

# %%
from matplotlib import pyplot as plt

# %matplotlib inline
plt.scatter(df0["sepal length (cm)"], df0['sepal width (cm)'], color ='red', marker ='*')
plt.scatter(df1["sepal length (cm)"], df1['sepal width (cm)'], color = 'blue', marker = '+')
# plt.scatter(df2["sepal length (cm)"], df2['sepal width (cm)'], color = 'green', marker = 'x')

# %%
# %matplotlib inline
plt.scatter(df0["petal length (cm)"], df0['petal width (cm)'], color ='red', marker ='*')
plt.scatter(df1["petal length (cm)"], df1['petal width (cm)'], color = 'blue', marker = '+')

# %%
# above we hav eshown that the as per 2 features the dataframe is saparable but we will provide input all the 
# features to our dataset.

# %%
from sklearn.model_selection import train_test_split

inputs = df_1.drop(['target', 'flower_name'], axis = 'columns')
inputs
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
outputs = df_1[['target']]
outputs
# Out:
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 1 columns]

# %%
# splitting the data

X_train, X_test, y_train, y_test = train_test_split(inputs, outputs, test_size = 0.2)

# %%
# importing model and training the model

X_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120, 1)

# %%
from sklearn.svm import SVC
model = SVC(kernel = 'linear')  # here if we will do SVC(C=10), SVC(kernel = 'linear'), SVC(gamma =10) increaseing the C value will decrese the regularizer and hence the 
# margin width will increse and the classifier will not classify the data precisely. 

model.fit(X_train, y_train)
# Out:
# /Users/pavankumar/.pyenv/versions/3.8.10/lib/python3.8/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
# from above we have trained our SVM model now we will check the accuracy of the model.

model.score(X_test, y_test)
# Out:
# 0.9666666666666667
