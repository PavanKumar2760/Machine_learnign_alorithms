# %% [markdown]
# # Training of the logistic regression model with the below conditions.
#
# Condition -1 >   Source_Z = "VI"      - To filter out all the correct data points with Z_VI as a bench mark
#
# Condition -2 >   Z_VI > 0.002  -  Condition for finding the data points which are visually observed.
#
# Outlier condition > abs[(" Z_VI - Z_PIPE") >0.1 * (1+"Z_VI")]
#
# Inlier condition > abs[(" Z_VI - Z_PIPE”) <0.05 * (1+"Z_VI”)]

# %% [markdown]
# # Reading the QR 16 catalog data.

# %%
import numpy as np  # it take care of all the arrays and mathematical operation in the fits files. 
from astropy.table import Table # for reading fits files.
import pandas as pd 
import matplotlib.pyplot as plt 
import statsmodels.api as sm
import random
import seaborn as sns
from sklearn import preprocessing
from collections import Counter
import warnings 
warnings.filterwarnings("ignore", category =DeprecationWarning)
import seaborn as sns

file = Table.read("DR16Q_v4.fits" )  # opening the fits files


"""
F = file['Z_VI', 'Z_PIPE']
file.add_index('Z_VI')
file
file
F_D = file[file['Z_VI'] >= 0]  # All the data whose Z_VI >= 0 
F_D[:2]
file.columns      # to call all the names of columns.
now we can get the information about the fits files from below code

"""
file.columns
# Out:
# <TableColumns names=('SDSS_NAME','RA','DEC','PLATE','MJD','FIBERID','AUTOCLASS_PQN','AUTOCLASS_DR14Q','IS_QSO_QN','Z_QN','RANDOM_SELECT','Z_10K','Z_CONF_10K','PIPE_CORR_10K','IS_QSO_10K','THING_ID','Z_VI','Z_CONF','CLASS_PERSON','Z_DR12Q','IS_QSO_DR12Q','Z_DR7Q_SCH','IS_QSO_DR7Q','Z_DR6Q_HW','Z_DR7Q_HW','IS_QSO_FINAL','Z','SOURCE_Z','Z_PIPE','ZWARNING','OBJID','Z_PCA','ZWARN_PCA','DELTACHI2_PCA','Z_HALPHA','ZWARN_HALPHA','DELTACHI2_HALPHA','Z_HBETA','ZWARN_HBETA','DELTACHI2_HBETA','Z_MGII','ZWARN_MGII','DELTACHI2_MGII','Z_CIII','ZWARN_CIII','DELTACHI2_CIII','Z_CIV','ZWARN_CIV','DELTACHI2_CIV','Z_LYA','ZWARN_LYA','DELTACHI2_LYA','Z_LYAWG','Z_DLA','NHI_DLA','CONF_DLA','BAL_PROB','BI_CIV','ERR_BI_CIV','AI_CIV','ERR_AI_CIV','BI_SIIV','ERR_BI_SIIV','AI_SIIV','ERR_AI_SIIV','BOSS_TARGET1','EBOSS_TARGET0','EBOSS_TARGET1','EBOSS_TARGET2','ANCILLARY_TARGET1','ANCILLARY_TARGET2','NSPEC_SDSS','NSPEC_BOSS','NSPEC','PLATE_DUPLICATE','MJD_DUPLICATE','FIBERID_DUPLICATE','SPECTRO_DUPLICATE','SKYVERSION','RUN_NUMBER','RERUN_NUMBER','CAMCOL_NUMBER','FIELD_NUMBER','ID_NUMBER','LAMBDA_EFF','ZOFFSET','XFOCAL','YFOCAL','CHUNK','TILE','PLATESN2','PSFFLUX','PSFFLUX_IVAR','PSFMAG','PSFMAGERR','EXTINCTION','M_I','SN_MEDIAN_ALL','GALEX_MATCHED','FUV','FUV_IVAR','NUV','NUV_IVAR','UKIDSS_MATCHED','YFLUX','YFLUX_ERR','JFLUX','JFLUX_ERR','HFLUX','HFLUX_ERR','KFLUX','KFLUX_ERR','W1_FLUX','W1_FLUX_IVAR','W1_MAG','W1_MAG_ERR','W1_CHI2','W1_FLUX_SNR','W1_SRC_FRAC','W1_EXT_FLUX','W1_EXT_FRAC','W1_NPIX','W2_FLUX','W2_FLUX_IVAR','W2_MAG','W2_MAG_ERR','W2_CHI2','W2_FLUX_SNR','W2_SRC_FRAC','W2_EXT_FLUX','W2_EXT_FRAC','W2_NPIX','FIRST_MATCHED','FIRST_FLUX','FIRST_SNR','SDSS2FIRST_SEP','JMAG','JMAG_ERR','JSNR','JRDFLAG','HMAG','HMAG_ERR','HSNR','HRDFLAG','KMAG','KMAG_ERR','KSNR','KRDFLAG','SDSS2MASS_SEP','2RXS_ID','2RXS_RA','2RXS_DEC','2RXS_SRC_FLUX','2RXS_SRC_FLUX_ERR','SDSS2ROSAT_SEP','XMM_SRC_ID','XMM_RA','XMM_DEC','XMM_SOFT_FLUX','XMM_SOFT_FLUX_ERR','XMM_HARD_FLUX','XMM_HARD_FLUX_ERR','XMM_TOTAL_FLUX','XMM_TOTAL_FLUX_ERR','XMM_TOTAL_LUM','SDSS2XMM_SEP','GAIA_MATCHED','GAIA_DESIGNATION','GAIA_RA','GAIA_DEC','GAIA_PARALLAX','GAIA_PARALLAX_ERR','GAIA_PM_RA','GAIA_PM_RA_ERR','GAIA_PM_DEC','GAIA_PM_DEC_ERR','GAIA_G_MAG','GAIA_G_FLUX_SNR','GAIA_BP_MAG','GAIA_BP_FLUX_SNR','GAIA_RP_MAG','GAIA_RP_FLUX_SNR','SDSS2GAIA_SEP')>

# %%
DF = file['Z_PIPE','ZWARNING','Z_PCA','ZWARN_PCA','DELTACHI2_PCA','Z','Z_HALPHA','ZWARN_HALPHA','DELTACHI2_HALPHA','Z_HBETA','ZWARN_HBETA','DELTACHI2_HBETA','Z_MGII','ZWARN_MGII','DELTACHI2_MGII','Z_CIII','ZWARN_CIII','DELTACHI2_CIII','Z_CIV','ZWARN_CIV','DELTACHI2_CIV','Z_LYA','ZWARN_LYA','DELTACHI2_LYA','Z_LYAWG','BAL_PROB','BI_CIV','ERR_BI_CIV','AI_CIV','ERR_AI_CIV','BI_SIIV','ERR_BI_SIIV','AI_SIIV','Z_VI','SOURCE_Z']
DF['Z_VI-Z_PIPE'] = abs(DF['Z_VI'] -DF['Z_PIPE'])
df_0 = DF
df_0
# Out:
# <Table length=750414>
#       Z_PIPE       ZWARNING ... SOURCE_Z      Z_VI-Z_PIPE
#      float64        int32   ... bytes12         float64
# ------------------ -------- ... -------- ---------------------
# 0.8454347848892212        0 ...     PIPE    1.8454347848892212
#  2.035491466522217        0 ...     PIPE     3.035491466522217
# 1.5742274522781372        0 ...     PIPE     2.574227452278137
# 1.7705516815185547        0 ...     PIPE    2.7705516815185547
#  2.024146318435669        0 ...     PIPE     3.024146318435669
#   2.30739688873291        0 ...       VI 0.0016031112670900072
#                ...      ... ...      ...                   ...
# 2.4156601428985596        0 ...       VI 0.0006601428985595348
# 1.4903559684753418        0 ...     PIPE     2.490355968475342
#  2.449492931365967        0 ...       VI 0.0025070686340331605
# 3.1141908168792725        0 ...       VI  0.005190816879272475
# 1.2329624891281128        0 ...     PIPE     2.232962489128113
# 2.0098648071289062        0 ...     PIPE    3.0098648071289062
# 2.3979172706604004        0 ...       VI   0.02291727066040039

# %% [markdown]
# # Condition SOURCE_Z == VI

# %%
df_con1 = df_0[(df_0['SOURCE_Z']== ['VI'])]
df_con1
# Out:
# <Table length=319596>
#       Z_PIPE       ZWARNING ... SOURCE_Z      Z_VI-Z_PIPE
#      float64        int32   ... bytes12         float64
# ------------------ -------- ... -------- ---------------------
#   2.30739688873291        0 ...       VI 0.0016031112670900072
# 0.2499377280473709        0 ...       VI 6.227195262908936e-05
#  2.497960329055786        0 ...       VI 0.0009603290557862465
# 1.6176164150238037        0 ...       VI 0.0013835849761962837
# 1.3597235679626465        0 ...       VI 0.0002764320373536133
# 2.3330492973327637        0 ...       VI  0.005049297332763825
#                ...      ... ...      ...                   ...
# 2.1797664165496826        0 ...       VI  0.019233583450317226
#  2.438377618789673        0 ...       VI 0.0006223812103272053
#   2.18566632270813        0 ...       VI  0.019333677291870188
# 2.4156601428985596        0 ...       VI 0.0006601428985595348
#  2.449492931365967        0 ...       VI 0.0025070686340331605
# 3.1141908168792725        0 ...       VI  0.005190816879272475
# 2.3979172706604004        0 ...       VI   0.02291727066040039

# %% [markdown]
# # Z_VI >= 0.002

# %%
df_con2 = df_con1[df_con1['Z_VI']>=0.002]
df_con2
# Out:
# <Table length=319283>
#       Z_PIPE       ZWARNING ... SOURCE_Z      Z_VI-Z_PIPE
#      float64        int32   ... bytes12         float64
# ------------------ -------- ... -------- ---------------------
#   2.30739688873291        0 ...       VI 0.0016031112670900072
# 0.2499377280473709        0 ...       VI 6.227195262908936e-05
#  2.497960329055786        0 ...       VI 0.0009603290557862465
# 1.6176164150238037        0 ...       VI 0.0013835849761962837
# 1.3597235679626465        0 ...       VI 0.0002764320373536133
# 2.3330492973327637        0 ...       VI  0.005049297332763825
#                ...      ... ...      ...                   ...
# 2.1797664165496826        0 ...       VI  0.019233583450317226
#  2.438377618789673        0 ...       VI 0.0006223812103272053
#   2.18566632270813        0 ...       VI  0.019333677291870188
# 2.4156601428985596        0 ...       VI 0.0006601428985595348
#  2.449492931365967        0 ...       VI 0.0025070686340331605
# 3.1141908168792725        0 ...       VI  0.005190816879272475
# 2.3979172706604004        0 ...       VI   0.02291727066040039

# %% [markdown]
# # Labeling the data

# %%
df_con2['LABEL'] = 2

# df_con2 = df_con21[df_con21['Z_VI-Z_PIPE']>(0.1*(1+df_con21['Z_VI']))]
# df_con2

# Outlier condition > 

condition_1= df_con2['Z_VI-Z_PIPE'] > 0.1 * (1+df_con2['Z']) 

# Inlier condition > 

condition_2 = df_con2['Z_VI-Z_PIPE'] <0.05 *(1+ df_con2['Z'])

# laleling the data with LABEL = 0 outlier, LABEL = 1 inlier 

df_con2['LABEL'][condition_1] = 0
df_con2['LABEL'][condition_2] = 1
df_con2
# Out:
# <Table length=319283>
#       Z_PIPE       ZWARNING       Z_PCA        ...      Z_VI-Z_PIPE      LABEL
#      float64        int32        float64       ...        float64        int64
# ------------------ -------- ------------------ ... --------------------- -----
#   2.30739688873291        0  2.309822022231934 ... 0.0016031112670900072     1
# 0.2499377280473709        0 0.2499664631139367 ... 6.227195262908936e-05     1
#  2.497960329055786        0  2.495224574735003 ... 0.0009603290557862465     1
# 1.6176164150238037        0  1.617289246338699 ... 0.0013835849761962837     1
# 1.3597235679626465        0 1.3608132894867597 ... 0.0002764320373536133     1
# 2.3330492973327637        0 2.3324270241186236 ...  0.005049297332763825     1
#                ...      ...                ... ...                   ...   ...
# 2.1797664165496826        0  2.177395252974738 ...  0.019233583450317226     1
#  2.438377618789673        0  2.435264652930172 ... 0.0006223812103272053     1
#   2.18566632270813        0 2.1817760339311802 ...  0.019333677291870188     1
# 2.4156601428985596        0 2.4124468414693605 ... 0.0006601428985595348     1
#  2.449492931365967        0  2.447446250077869 ... 0.0025070686340331605     1
# 3.1141908168792725        0  3.106479602963368 ...  0.005190816879272475     1
# 2.3979172706604004        0  2.397574701917856 ...   0.02291727066040039     1

# %% [markdown]
# # DATA with only outliers and inliers = 319341 In which we have done the analysis.

# %%
df = df_con2[df_con2['LABEL']!= 2]
df
# Out:
# <Table length=319032>
#       Z_PIPE       ZWARNING       Z_PCA        ...      Z_VI-Z_PIPE      LABEL
#      float64        int32        float64       ...        float64        int64
# ------------------ -------- ------------------ ... --------------------- -----
#   2.30739688873291        0  2.309822022231934 ... 0.0016031112670900072     1
# 0.2499377280473709        0 0.2499664631139367 ... 6.227195262908936e-05     1
#  2.497960329055786        0  2.495224574735003 ... 0.0009603290557862465     1
# 1.6176164150238037        0  1.617289246338699 ... 0.0013835849761962837     1
# 1.3597235679626465        0 1.3608132894867597 ... 0.0002764320373536133     1
# 2.3330492973327637        0 2.3324270241186236 ...  0.005049297332763825     1
#                ...      ...                ... ...                   ...   ...
# 2.1797664165496826        0  2.177395252974738 ...  0.019233583450317226     1
#  2.438377618789673        0  2.435264652930172 ... 0.0006223812103272053     1
#   2.18566632270813        0 2.1817760339311802 ...  0.019333677291870188     1
# 2.4156601428985596        0 2.4124468414693605 ... 0.0006601428985595348     1
#  2.449492931365967        0  2.447446250077869 ... 0.0025070686340331605     1
# 3.1141908168792725        0  3.106479602963368 ...  0.005190816879272475     1
# 2.3979172706604004        0  2.397574701917856 ...   0.02291727066040039     1

# %%
df = df.to_pandas()
df
# Out:
#           Z_PIPE  ZWARNING     Z_PCA  ZWARN_PCA  DELTACHI2_PCA      Z  \
# 0       2.307397         0  2.309822          0    2041.861057  2.309
# 1       0.249938         0  0.249966          0   10312.022278  0.250
# 2       2.497960         0  2.495225          0    4279.918211  2.497
# 3       1.617616         0  1.617289          0    2050.736266  1.619
# 4       1.359724         0  1.360813          0    9258.567133  1.360
# ...          ...       ...       ...        ...            ...    ...
# 319027  2.185666         0  2.181776          0    6389.049799  2.205
# 319028  2.415660         0  2.412447          0    2715.918250  2.415
# 319029  2.449493         0  2.447446          0   12948.259371  2.452
# 319030  3.114191         0  3.106480          0   13097.088163  3.109
# 319031  2.397917         0  2.397575          0    2172.760364  2.375
#
#         Z_HALPHA  ZWARN_HALPHA  DELTACHI2_HALPHA   Z_HBETA  ...  ERR_BI_CIV  \
# 0      -1.000000          7682          0.000000 -1.000000  ...         0.0
# 1       0.250266             0       2179.694192  0.250295  ...        -1.0
# 2      -1.000000          7682          0.000000 -1.000000  ...         0.0
# 3      -1.000000          7682          0.000000 -1.000000  ...         0.0
# 4      -1.000000          7682          0.000000 -1.000000  ...        -1.0
# ...          ...           ...               ...       ...  ...         ...
# 319027 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319028 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319029 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319030 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319031 -1.000000          7682          0.000000 -1.000000  ...         0.0
#
#              AI_CIV  ERR_AI_CIV  BI_SIIV  ERR_BI_SIIV     AI_SIIV   Z_VI  \
# 0          0.000000    0.000000      0.0          0.0    0.000000  2.309
# 1         -1.000000   -1.000000     -1.0         -1.0   -1.000000  0.250
# 2          0.000000    0.000000      0.0          0.0   58.435139  2.497
# 3          0.000000    0.000000      0.0          0.0    0.000000  1.619
# 4         -1.000000   -1.000000     -1.0         -1.0   -1.000000  1.360
# ...             ...         ...      ...          ...         ...    ...
# 319027     0.000000    0.000000      0.0          0.0   55.908417  2.205
# 319028   536.268921   14.119609      0.0          0.0  312.070557  2.415
# 319029   224.305267    9.015470      0.0          0.0    0.000000  2.452
# 319030     0.000000    0.000000      0.0          0.0    0.000000  3.109
# 319031  2452.570557   12.860671      0.0          0.0   53.452263  2.375
#
#         SOURCE_Z  Z_VI-Z_PIPE  LABEL
# 0          b'VI'     0.001603      1
# 1          b'VI'     0.000062      1
# 2          b'VI'     0.000960      1
# 3          b'VI'     0.001384      1
# 4          b'VI'     0.000276      1
# ...          ...          ...    ...
# 319027     b'VI'     0.019334      1
# 319028     b'VI'     0.000660      1
# 319029     b'VI'     0.002507      1
# 319030     b'VI'     0.005191      1
# 319031     b'VI'     0.022917      1
#
# [319032 rows x 37 columns]

# %% [markdown]
# # Points those are neither outliers nor-inliers = 251

# %%
NINO = df_con2[df_con2['LABEL']==2]
NINO
# Out:
# <Table length=251>
#       Z_PIPE       ZWARNING       Z_PCA        ...     Z_VI-Z_PIPE     LABEL
#      float64        int32        float64       ...       float64       int64
# ------------------ -------- ------------------ ... ------------------- -----
#  2.878774404525757        0 3.0150121109791685 ...  0.2532255954742433     2
# 2.2365541458129883       64 2.3951918619959365 ... 0.18644585418701176     2
#  3.081758975982666        0 2.8898736904922706 ... 0.24875897598266583     2
#  3.701228141784668        0  3.927976294274015 ...   0.278771858215332     2
#  3.309638261795044        0 3.5771827105313347 ...   0.263361738204956     2
#  2.477393627166748        4 2.6530599009493496 ... 0.21860637283325213     2
#                ...      ...                ... ...                 ...   ...
#  1.071600079536438       68 1.0175934526022816 ... 0.10760007953643802     2
#  2.539611577987671       64 2.7462676388119176 ... 0.26538842201232926     2
#  1.532497525215149        4 1.8054396120767455 ...  0.2755024747848511     2
# 1.2282006740570068        4 1.1046652734144815 ... 0.11320067405700684     2
# 1.1986300945281982        4 1.4278048374410788 ...  0.2283699054718018     2
# 0.8084624409675598        0 0.9575071113555085 ... 0.19153755903244019     2
# 1.3863893747329712        4 1.2457305679706039 ... 0.19538937473297113     2

# %% [markdown]
# # Outliers = 6588

# %%
Outliers = df[df['LABEL']==0]
Outliers
# Out:
#           Z_PIPE  ZWARNING     Z_PCA  ZWARN_PCA  DELTACHI2_PCA      Z  \
# 25      3.279791         0  0.859181          0     320.656086  0.858
# 30      2.813011         0  1.999616          0   21014.832218  2.001
# 47      5.371880         0  1.762738          0    9301.865191  1.760
# 53      1.127501         4  2.220196          0    6442.753447  2.239
# 65      2.845430         4  2.044132          0     298.406491  2.018
# ...          ...       ...       ...        ...            ...    ...
# 318907  3.344797         4  0.892422          0     242.518537  0.892
# 318936  4.795134         0  1.520291          0     468.259051  1.530
# 318944  6.431489         0  2.155029          0    1342.320256  2.253
# 318964  3.027531         4  0.765979          0    5183.509342  0.765
# 319009  3.565226         4  2.584312          0     411.210152  2.593
#
#         Z_HALPHA  ZWARN_HALPHA  DELTACHI2_HALPHA   Z_HBETA  ...  ERR_BI_CIV  \
# 25          -1.0          7682               0.0  0.846816  ...    -1.00000
# 30          -1.0          7682               0.0 -1.000000  ...     9.38902
# 47          -1.0          7682               0.0 -1.000000  ...     0.00000
# 53          -1.0          7682               0.0 -1.000000  ...     0.00000
# 65          -1.0          7682               0.0 -1.000000  ...     0.00000
# ...          ...           ...               ...       ...  ...         ...
# 318907      -1.0          7682               0.0  0.890442  ...    -1.00000
# 318936      -1.0          7682               0.0 -1.000000  ...    -1.00000
# 318944      -1.0          7682               0.0 -1.000000  ...     0.00000
# 318964      -1.0          7682               0.0  0.765663  ...    -1.00000
# 319009      -1.0          7682               0.0 -1.000000  ...     0.00000
#
#              AI_CIV  ERR_AI_CIV      BI_SIIV  ERR_BI_SIIV      AI_SIIV   Z_VI  \
# 25        -1.000000   -1.000000    -1.000000    -1.000000    -1.000000  0.858
# 30      7798.923340   11.533576  3598.900391     9.976647  4590.666504  2.001
# 47         0.000000    0.000000     0.000000     0.000000     0.000000  1.760
# 53         0.000000    0.000000     0.000000     0.000000     0.000000  2.239
# 65       547.576294    9.557714     0.000000     0.000000     0.000000  2.018
# ...             ...         ...          ...          ...          ...    ...
# 318907    -1.000000   -1.000000    -1.000000    -1.000000    -1.000000  0.892
# 318936    -1.000000   -1.000000    -1.000000    -1.000000    -1.000000  1.530
# 318944  7430.056152  111.965218     0.000000     0.000000   109.800179  2.253
# 318964    -1.000000   -1.000000    -1.000000    -1.000000    -1.000000  0.765
# 319009     0.000000    0.000000     0.000000     0.000000     0.000000  2.593
#
#         SOURCE_Z  Z_VI-Z_PIPE  LABEL
# 25         b'VI'     2.421791      0
# 30         b'VI'     0.812011      0
# 47         b'VI'     3.611880      0
# 53         b'VI'     1.111499      0
# 65         b'VI'     0.827430      0
# ...          ...          ...    ...
# 318907     b'VI'     2.452797      0
# 318936     b'VI'     3.265134      0
# 318944     b'VI'     4.178489      0
# 318964     b'VI'     2.262531      0
# 319009     b'VI'     0.972226      0
#
# [6588 rows x 37 columns]

# %% [markdown]
# # Inliers = 312444

# %%
Inliers  = df[df['LABEL']==1]
Inliers
# Out:
#           Z_PIPE  ZWARNING     Z_PCA  ZWARN_PCA  DELTACHI2_PCA      Z  \
# 0       2.307397         0  2.309822          0    2041.861057  2.309
# 1       0.249938         0  0.249966          0   10312.022278  0.250
# 2       2.497960         0  2.495225          0    4279.918211  2.497
# 3       1.617616         0  1.617289          0    2050.736266  1.619
# 4       1.359724         0  1.360813          0    9258.567133  1.360
# ...          ...       ...       ...        ...            ...    ...
# 319027  2.185666         0  2.181776          0    6389.049799  2.205
# 319028  2.415660         0  2.412447          0    2715.918250  2.415
# 319029  2.449493         0  2.447446          0   12948.259371  2.452
# 319030  3.114191         0  3.106480          0   13097.088163  3.109
# 319031  2.397917         0  2.397575          0    2172.760364  2.375
#
#         Z_HALPHA  ZWARN_HALPHA  DELTACHI2_HALPHA   Z_HBETA  ...  ERR_BI_CIV  \
# 0      -1.000000          7682          0.000000 -1.000000  ...         0.0
# 1       0.250266             0       2179.694192  0.250295  ...        -1.0
# 2      -1.000000          7682          0.000000 -1.000000  ...         0.0
# 3      -1.000000          7682          0.000000 -1.000000  ...         0.0
# 4      -1.000000          7682          0.000000 -1.000000  ...        -1.0
# ...          ...           ...               ...       ...  ...         ...
# 319027 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319028 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319029 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319030 -1.000000          7682          0.000000 -1.000000  ...         0.0
# 319031 -1.000000          7682          0.000000 -1.000000  ...         0.0
#
#              AI_CIV  ERR_AI_CIV  BI_SIIV  ERR_BI_SIIV     AI_SIIV   Z_VI  \
# 0          0.000000    0.000000      0.0          0.0    0.000000  2.309
# 1         -1.000000   -1.000000     -1.0         -1.0   -1.000000  0.250
# 2          0.000000    0.000000      0.0          0.0   58.435139  2.497
# 3          0.000000    0.000000      0.0          0.0    0.000000  1.619
# 4         -1.000000   -1.000000     -1.0         -1.0   -1.000000  1.360
# ...             ...         ...      ...          ...         ...    ...
# 319027     0.000000    0.000000      0.0          0.0   55.908417  2.205
# 319028   536.268921   14.119609      0.0          0.0  312.070557  2.415
# 319029   224.305267    9.015470      0.0          0.0    0.000000  2.452
# 319030     0.000000    0.000000      0.0          0.0    0.000000  3.109
# 319031  2452.570557   12.860671      0.0          0.0   53.452263  2.375
#
#         SOURCE_Z  Z_VI-Z_PIPE  LABEL
# 0          b'VI'     0.001603      1
# 1          b'VI'     0.000062      1
# 2          b'VI'     0.000960      1
# 3          b'VI'     0.001384      1
# 4          b'VI'     0.000276      1
# ...          ...          ...    ...
# 319027     b'VI'     0.019334      1
# 319028     b'VI'     0.000660      1
# 319029     b'VI'     0.002507      1
# 319030     b'VI'     0.005191      1
# 319031     b'VI'     0.022917      1
#
# [312444 rows x 37 columns]

# %%
level_counts = df['LABEL'].value_counts()
level_counts
# Out:
# LABEL
# 1    312444
# 0      6588
# Name: count, dtype: int64

# %%
level_counts.index
# Out:
# Index([1, 0], dtype='int64', name='LABEL')

# %%
# plt.xlabel('class')
# plt.ylabel('count')
# plt.title('Bar plot of inliers vs outliers')
# plt.bar(df['LABEL'], [Inliers, Outliers], color = ['blue', 'green'])
# plt.show()

# %%
level_counts.values
# Out:
# array([312444,   6588])

# %%
# %matplotlib inline 
bars = plt.bar(level_counts.index, level_counts.values, color = ['green', 'red'])

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom', ha='center', fontsize=10, color='black')
# plt.xlabel("Imbalanced dataset")
plt.ylabel("Counts")
plt.title("Imbalanced Dataset")
plt.xticks(level_counts.index, ['Inliers', "Outliers"])
plt.show()

# %% [markdown]
# # Balancing the data set with under sampling.

# %%
Outliers_training_d = Outliers.sample(level_counts.values[0], replace = True)
Outliers_training_d
df_training_d = pd.concat([Outliers_training_d, Inliers], axis = 0) # training data-set
df_training_d.shape

level_counts_d = df_training_d['LABEL'].value_counts()
# %matplotlib inline 
bars = plt.bar(level_counts_d.index, level_counts_d.values, color = ['red', 'green'])

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom', ha='center', fontsize=10, color='black')
# plt.xlabel("Imbalanced dataset")
plt.ylabel("Counts")
plt.title("Balanced Dataset using Over sampling")
plt.xticks(level_counts.index, ['Inliers', "Outliers"])
plt.show()

# %% [markdown]
# # Trainign model in Over_sampling balanced data set

# %%
# final dataset

df_training_d = df_training_d.dropna(axis=1)
df_training_d
df_t_d = df_training_d[['Z_PIPE', 'ZWARNING', 'Z_PCA', 'ZWARN_PCA', 'DELTACHI2_PCA',
       'Z_HALPHA', 'ZWARN_HALPHA', 'DELTACHI2_HALPHA', 'Z_HBETA',
       'ZWARN_HBETA', 'DELTACHI2_HBETA', 'Z_MGII', 'ZWARN_MGII',
       'DELTACHI2_MGII', 'Z_CIII', 'ZWARN_CIII', 'DELTACHI2_CIII', 'Z_CIV',
       'ZWARN_CIV', 'DELTACHI2_CIV', 'Z_LYA', 'ZWARN_LYA', 'DELTACHI2_LYA',
       'Z_LYAWG', 'BAL_PROB', 'BI_CIV', 'AI_CIV',
       'BI_SIIV', 'AI_SIIV',
       'LABEL']]
X, y = df_t_d.iloc[:,:-1], df_t_d.iloc[:,-1]
from sklearn.model_selection import train_test_split 
X_train_test, X_val, y_train_test, y_val = train_test_split(X, y, test_size = 0.15)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kf = KFold(n_splits = 4, shuffle =True, random_state = 42)
kf
# Out:
# KFold(n_splits=4, random_state=42, shuffle=True)

# %%
df_training_d.iloc[:, :10]
# Out:
#           Z_PIPE  ZWARNING     Z_PCA  ZWARN_PCA  DELTACHI2_PCA      Z  \
# 70843   1.665327         0  1.157549          0     124.373526  1.110
# 198118  3.402716        64  1.607100          0    2211.769286  1.605
# 75725   4.380836         4  1.348030          0      45.684040  1.351
# 234767  4.057529         4  1.223875          0     178.424696  1.230
# 26438   2.953096         4  2.121533          0     154.352153  2.120
# ...          ...       ...       ...        ...            ...    ...
# 319027  2.185666         0  2.181776          0    6389.049799  2.205
# 319028  2.415660         0  2.412447          0    2715.918250  2.415
# 319029  2.449493         0  2.447446          0   12948.259371  2.452
# 319030  3.114191         0  3.106480          0   13097.088163  3.109
# 319031  2.397917         0  2.397575          0    2172.760364  2.375
#
#         Z_HALPHA  ZWARN_HALPHA  DELTACHI2_HALPHA  Z_HBETA
# 70843       -1.0          7682               0.0     -1.0
# 198118      -1.0          7682               0.0     -1.0
# 75725       -1.0          7682               0.0     -1.0
# 234767      -1.0          7682               0.0     -1.0
# 26438       -1.0          7682               0.0     -1.0
# ...          ...           ...               ...      ...
# 319027      -1.0          7682               0.0     -1.0
# 319028      -1.0          7682               0.0     -1.0
# 319029      -1.0          7682               0.0     -1.0
# 319030      -1.0          7682               0.0     -1.0
# 319031      -1.0          7682               0.0     -1.0
#
# [624888 rows x 10 columns]

# %%
val_scores = []
test_scores = []

from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter= 2000000000000)

for train_index, test_index in kf.split(X_train_test):
    X_train_fold, X_test_fold = X_train_test.iloc[train_index], X_train_test.iloc[test_index]
    y_train_fold, y_test_fold = y_train_test.iloc[train_index], y_train_test.iloc[test_index]
    model.fit(X_train_fold, y_train_fold)
    
    # evaluation on validation set 
    
    val_score = model.score(X_test_fold, y_test_fold)
    val_scores.append(val_score)
    
    # Evaluation on test set 
    
    test_score = model.score(X_val, y_val)
    test_scores.append(test_score)


print(f"mean_val_score = {np.mean(val_scores)}")
print(f"mean_test_score = {np.mean(test_scores)}")
# Out:
# mean_val_score = 0.8275829634093123
# mean_test_score = 0.828914801459449

# %%
scores_data = {
    'Score_Type': ['Validation_Score', 'Test_Score'],
    'Mean_Score': [np.mean(val_scores), np.mean(test_scores)]
}

scores_df = pd.DataFrame(scores_data)
scores_df
# Out:
#          Score_Type  Mean_Score
# 0  Validation_Score    0.827583
# 1        Test_Score    0.828915

# %%
# %matplotlib inline 
plt.figure(figsize =(6,6))
bars = plt.bar(scores_df['Score_Type'], scores_df['Mean_Score'],color= ['b', 'g'] )
plt.title('Model score in validation and test data set while using over sampling method ')
plt.ylabel('score in percentage')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, f'{yval:.2f}', ha='center', va='bottom', fontsize=10)

plt.show()

# %%
def feature_weightage(Coefficient, feature_name):
    importance = (
        pd.DataFrame(
    
        { 
         "Model_Features": feature_name,  
         "Coefficient" : Coefficient
        }  
    
    )
    .sort_values("Coefficient", ascending = False)\
    .style.bar(color =['red','green'], align ='zero')
    )
    
    return importance

# %%
feature_weightage(model.coef_[0],X_val.columns)
# Out:
# <style type="text/css">
# #T_bb3f7_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 81.9%, transparent 81.9%);
# }
# #T_bb3f7_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 68.1%, transparent 68.1%);
# }
# #T_bb3f7_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.4%, transparent 66.4%);
# }
# #T_bb3f7_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 65.6%, transparent 65.6%);
# }
# #T_bb3f7_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 64.0%, transparent 64.0%);
# }
# #T_bb3f7_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 52.0%, transparent 52.0%);
# }
# #T_bb3f7_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.7%, transparent 51.7%);
# }
# #T_bb3f7_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.2%, transparent 51.2%);
# }
# #T_bb3f7_row8_col1, #T_bb3f7_row9_col1, #T_bb3f7_row10_col1, #T_bb3f7_row11_col1, #T_bb3f7_row12_col1, #T_bb3f7_row13_col1, #T_bb3f7_row14_col1, #T_bb3f7_row15_col1, #T_bb3f7_row16_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, green 50.0%, green 50.0%, transparent 50.0%);
# }
# #T_bb3f7_row17_col1, #T_bb3f7_row18_col1, #T_bb3f7_row19_col1, #T_bb3f7_row20_col1, #T_bb3f7_row21_col1, #T_bb3f7_row22_col1, #T_bb3f7_row23_col1, #T_bb3f7_row24_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, red 50.0%, red 50.0%, transparent 50.0%);
# }
# #T_bb3f7_row25_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.7%, red 49.7%, red 50.0%, transparent 50.0%);
# }
# #T_bb3f7_row26_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 49.1%, red 49.1%, red 50.0%, transparent 50.0%);
# }
# #T_bb3f7_row27_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 44.2%, red 44.2%, red 50.0%, transparent 50.0%);
# }
# #T_bb3f7_row28_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, red 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_bb3f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb3f7_level0_col0" class="col_heading level0 col0" >Model_Features</th>
#       <th id="T_bb3f7_level0_col1" class="col_heading level0 col1" >Coefficient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb3f7_level0_row0" class="row_heading level0 row0" >23</th>
#       <td id="T_bb3f7_row0_col0" class="data row0 col0" >Z_LYAWG</td>
#       <td id="T_bb3f7_row0_col1" class="data row0 col1" >0.481031</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_bb3f7_row1_col0" class="data row1 col0" >Z_MGII</td>
#       <td id="T_bb3f7_row1_col1" class="data row1 col1" >0.272862</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row2" class="row_heading level0 row2" >14</th>
#       <td id="T_bb3f7_row2_col0" class="data row2 col0" >Z_CIII</td>
#       <td id="T_bb3f7_row2_col1" class="data row2 col1" >0.247363</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row3" class="row_heading level0 row3" >17</th>
#       <td id="T_bb3f7_row3_col0" class="data row3 col0" >Z_CIV</td>
#       <td id="T_bb3f7_row3_col1" class="data row3 col1" >0.234828</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_bb3f7_row4_col0" class="data row4 col0" >Z_PCA</td>
#       <td id="T_bb3f7_row4_col1" class="data row4 col1" >0.211164</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bb3f7_row5_col0" class="data row5 col0" >Z_HALPHA</td>
#       <td id="T_bb3f7_row5_col1" class="data row5 col1" >0.030831</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row6" class="row_heading level0 row6" >20</th>
#       <td id="T_bb3f7_row6_col0" class="data row6 col0" >Z_LYA</td>
#       <td id="T_bb3f7_row6_col1" class="data row6 col1" >0.026340</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_bb3f7_row7_col0" class="data row7 col0" >Z_HBETA</td>
#       <td id="T_bb3f7_row7_col1" class="data row7 col1" >0.017736</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_bb3f7_row8_col0" class="data row8 col0" >DELTACHI2_HBETA</td>
#       <td id="T_bb3f7_row8_col1" class="data row8 col1" >0.000688</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row9" class="row_heading level0 row9" >25</th>
#       <td id="T_bb3f7_row9_col0" class="data row9 col0" >BI_CIV</td>
#       <td id="T_bb3f7_row9_col1" class="data row9 col1" >0.000400</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row10" class="row_heading level0 row10" >22</th>
#       <td id="T_bb3f7_row10_col0" class="data row10 col0" >DELTACHI2_LYA</td>
#       <td id="T_bb3f7_row10_col1" class="data row10 col1" >0.000134</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_bb3f7_row11_col0" class="data row11 col0" >ZWARN_MGII</td>
#       <td id="T_bb3f7_row11_col1" class="data row11 col1" >0.000107</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row12" class="row_heading level0 row12" >15</th>
#       <td id="T_bb3f7_row12_col0" class="data row12 col0" >ZWARN_CIII</td>
#       <td id="T_bb3f7_row12_col1" class="data row12 col1" >0.000095</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row13" class="row_heading level0 row13" >18</th>
#       <td id="T_bb3f7_row13_col0" class="data row13 col0" >ZWARN_CIV</td>
#       <td id="T_bb3f7_row13_col1" class="data row13 col1" >0.000063</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row14" class="row_heading level0 row14" >16</th>
#       <td id="T_bb3f7_row14_col0" class="data row14 col0" >DELTACHI2_CIII</td>
#       <td id="T_bb3f7_row14_col1" class="data row14 col1" >0.000053</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row15" class="row_heading level0 row15" >4</th>
#       <td id="T_bb3f7_row15_col0" class="data row15 col0" >DELTACHI2_PCA</td>
#       <td id="T_bb3f7_row15_col1" class="data row15 col1" >0.000030</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row16" class="row_heading level0 row16" >27</th>
#       <td id="T_bb3f7_row16_col0" class="data row16 col0" >BI_SIIV</td>
#       <td id="T_bb3f7_row16_col1" class="data row16 col1" >0.000017</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row17" class="row_heading level0 row17" >6</th>
#       <td id="T_bb3f7_row17_col0" class="data row17 col0" >ZWARN_HALPHA</td>
#       <td id="T_bb3f7_row17_col1" class="data row17 col1" >-0.000006</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row18" class="row_heading level0 row18" >21</th>
#       <td id="T_bb3f7_row18_col0" class="data row18 col0" >ZWARN_LYA</td>
#       <td id="T_bb3f7_row18_col1" class="data row18 col1" >-0.000037</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row19" class="row_heading level0 row19" >13</th>
#       <td id="T_bb3f7_row19_col0" class="data row19 col0" >DELTACHI2_MGII</td>
#       <td id="T_bb3f7_row19_col1" class="data row19 col1" >-0.000080</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row20" class="row_heading level0 row20" >9</th>
#       <td id="T_bb3f7_row20_col0" class="data row20 col0" >ZWARN_HBETA</td>
#       <td id="T_bb3f7_row20_col1" class="data row20 col1" >-0.000098</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row21" class="row_heading level0 row21" >19</th>
#       <td id="T_bb3f7_row21_col0" class="data row21 col0" >DELTACHI2_CIV</td>
#       <td id="T_bb3f7_row21_col1" class="data row21 col1" >-0.000124</td>
#     </tr>
#     <tr>
#       <th id="T_bb3f7_level0_row22" class="row_heading level0 row22" >7</th>
#       <td id="T_bb3f7_row22_col0" class="data row2

# %%
colors = ['red' if c < 0 else 'blue' for c in model.coef_[0]]
plt.figure(figsize=(12, 6))
plt.bar(X_val.columns, model.coef_[0], color = colors)
plt.xlabel('Model Features')
plt.ylabel('Coefficients')
plt.title('Bar Chart of Model Coefficients in Over Sampling method')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Model predictions in real time data

# %%
df[df['Z_VI']<=0]
# Out:
# Empty DataFrame
# Columns: [Z_PIPE, ZWARNING, Z_PCA, ZWARN_PCA, DELTACHI2_PCA, Z, Z_HALPHA, ZWARN_HALPHA, DELTACHI2_HALPHA, Z_HBETA, ZWARN_HBETA, DELTACHI2_HBETA, Z_MGII, ZWARN_MGII, DELTACHI2_MGII, Z_CIII, ZWARN_CIII, DELTACHI2_CIII, Z_CIV, ZWARN_CIV, DELTACHI2_CIV, Z_LYA, ZWARN_LYA, DELTACHI2_LYA, Z_LYAWG, BAL_PROB, BI_CIV, ERR_BI_CIV, AI_CIV, ERR_AI_CIV, BI_SIIV, ERR_BI_SIIV, AI_SIIV, Z_VI, SOURCE_Z, Z_VI-Z_PIPE, LABEL]
# Index: []
#
# [0 rows x 37 columns]

# %%
model.coef_[0]
# Out:
# array([-7.97365483e-01, -8.52012517e-02,  1.59522548e-01, -4.98028633e-03,
#         3.31940005e-05,  2.55466042e-01,  2.40110055e-02,  1.94963451e-06,
#        -2.00691065e-04,  9.68188903e-03, -1.09144091e-04,  5.12460028e-04,
#         2.29997082e-01,  8.21601043e-05, -8.88428808e-05,  1.94650314e-01,
#         8.58083125e-05,  3.93692764e-05,  1.85086030e-01,  5.31982532e-05,
#        -1.18545722e-04,  4.10886437e-05, -4.59594770e-05,  1.15727091e-04,
#         5.03114702e-01, -2.05422922e-02,  3.44688052e-04, -2.59120774e-04,
#         2.40893481e-05, -5.44777152e-04])

# %% [markdown]
# # Model prediction in the data set Z_VI <=0.002

# %%
df_p1 = df_0[df_0['Z_VI']<=0]
df_p11 = df_p1['Z_PIPE', 'ZWARNING', 'Z_PCA', 'ZWARN_PCA', 'DELTACHI2_PCA', 'Z',
       'Z_HALPHA', 'ZWARN_HALPHA', 'DELTACHI2_HALPHA', 'Z_HBETA',
       'ZWARN_HBETA', 'DELTACHI2_HBETA', 'Z_MGII', 'ZWARN_MGII',
       'DELTACHI2_MGII', 'Z_CIII', 'ZWARN_CIII', 'DELTACHI2_CIII', 'Z_CIV',
       'ZWARN_CIV', 'DELTACHI2_CIV', 'Z_LYA', 'ZWARN_LYA', 'DELTACHI2_LYA',
       'Z_LYAWG', 'BAL_PROB', 'BI_CIV', 'AI_CIV', 'BI_SIIV', 'AI_SIIV']
df_p111 = df_p11.to_pandas()
df_p111
prediction_1 = model.predict(df_p111)
len(prediction_1)
In_liers = print(np.sum(prediction_1==1))
Out_liers = print(np.sum(prediction_1 ==0))
# Out:
# 315462
# 112555

# %%
df_p2= df_con1[df_con1['Z_VI']<0]
df_p22 = df_p2['Z_PIPE', 'ZWARNING', 'Z_PCA', 'ZWARN_PCA', 'DELTACHI2_PCA', 'Z',
       'Z_HALPHA', 'ZWARN_HALPHA', 'DELTACHI2_HALPHA', 'Z_HBETA',
       'ZWARN_HBETA', 'DELTACHI2_HBETA', 'Z_MGII', 'ZWARN_MGII',
       'DELTACHI2_MGII', 'Z_CIII', 'ZWARN_CIII', 'DELTACHI2_CIII', 'Z_CIV',
       'ZWARN_CIV', 'DELTACHI2_CIV', 'Z_LYA', 'ZWARN_LYA', 'DELTACHI2_LYA',
       'Z_LYAWG', 'BAL_PROB', 'BI_CIV', 'AI_CIV', 'BI_SIIV', 'AI_SIIV']
df_p222 = df_p22.to_pandas()
prediction_2 = model.predict(df_p222)
len(prediction_2)
In__liers = print(np.sum(prediction_2 ==1))
Out__liers = print(np.sum(prediction_2 ==0))
# Out:
# 174
# 139

# %%
df_p1 = df_0[df_0['Z_VI']<=0]
df_p1
# Out:
# <Table length=428017>
#       Z_PIPE       ZWARNING       Z_PCA        ...   Z_VI  SOURCE_Z Z-Z_PIPE
#      float64        int32        float64       ... float64 bytes12  float64
# ------------------ -------- ------------------ ... ------- -------- --------
# 0.8454347848892212        0  0.845751479344974 ...    -1.0     PIPE      0.0
#  2.035491466522217        0 2.0344430019020106 ...    -1.0     PIPE      0.0
# 1.5742274522781372        0 1.5748324669819411 ...    -1.0     PIPE      0.0
# 1.7705516815185547        0 1.7711350379809114 ...    -1.0     PIPE      0.0
#  2.024146318435669        0 2.0259091237511564 ...    -1.0     PIPE      0.0
#  2.102771282196045        0  2.101496527515934 ...    -1.0     PIPE      0.0
#                ...      ...                ... ...     ...      ...      ...
#  2.019596576690674        0 2.0190560241833455 ...    -1.0     PIPE      0.0
# 1.3559542894363403        0 1.3556378010315973 ...    -1.0     PIPE      0.0
# 1.3968771696090698        0 1.3963632549561213 ...    -1.0     PIPE      0.0
#  3.309382915496826        0  3.310147538087328 ...    -1.0     PIPE      0.0
# 1.4903559684753418        0 1.4906091512796538 ...    -1.0     PIPE      0.0
# 1.2329624891281128        0 1.2333881856596423 ...    -1.0     PIPE      0.0
# 2.0098648071289062        0 2.0100155419078476 ...    -1.0     PIPE      0.0
