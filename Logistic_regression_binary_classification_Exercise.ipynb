# %% [markdown]
# In this exercise we will make a model for HR department that will predict that the
# Employee should be retained in the company or he needs to leave the company by the performance analysis. We are using Kaggle data set here.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
df = pd.read_csv("HR_comma_sep_logistic_regression.csv")
df.head(100)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 3                 0.72             0.87               5                   223
# 4                 0.37             0.52               2                   159
# ..                 ...              ...             ...                   ...
# 95                0.37             0.51               2                   155
# 96                0.10             0.77               6                   265
# 97                0.10             0.84               6                   279
# 98                0.11             0.97               6                   284
# 99                0.90             1.00               5                   221
#
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
# now here we will split our data in training and testing.

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = df
